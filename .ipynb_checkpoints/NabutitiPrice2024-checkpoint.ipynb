# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("housing.csv")

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value
# 0         322         126         8.3252              452600
# 1        2401        1138         8.3014              358500
# 2         496         177         7.2574              352100
# 3         558         219         5.6431              341300
# 4         565         259         3.8462              342200

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income  median_house_value
# 0             322         126         8.3252              452600
# 1            2401        1138         8.3014              358500
# 2             496         177         7.2574              352100
# 3             558         219         5.6431              341300
# 4             565         259         3.8462              342200
# ...           ...         ...            ...                 ...
# 20635         845         330         1.5603               78100
# 20636         356         114         2.5568               77100
# 20637        1007         433         1.7000               92300
# 20638         741         349         1.8672               84700
# 20639        1387         530         2.3886               89400
#
# [20640 rows x 9 columns]

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (20433, 9)

# %%
data.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 20635      False     False               False        False           False
# 20636      False     False               False        False           False
# 20637      False     False               False        False           False
# 20638      False     False               False        False           False
# 20639      False     False               False        False           False
#
#        population  households  median_income  median_house_value
# 0           False       False          False               False
# 1           False       False          False               False
# 2           False       False          False               False
# 3           False       False          False               False
# 4           False       False          False               False
# ...           ...         ...            ...                 ...
# 20635       False       False          False               False
# 20636       False       False          False               False
# 20637       False       False          False               False
# 20638       False       False          False               False
# 20639       False       False          False               False
#
# [20433 rows x 9 columns]

# %%
data. isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
data.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms             int64
# total_bedrooms        float64
# population              int64
# households              int64
# median_income         float64
# median_house_value      int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  int64
#  3   total_rooms         20433 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  int64
#  6   households          20433 non-null  int64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  int64
# dtypes: float64(4), int64(5)
# memory usage: 1.6 MB

# %%
data.describe().T
# Out:
#                       count           mean            std         min  \
# longitude           20433.0    -119.570689       2.003578   -124.3500
# latitude            20433.0      35.633221       2.136348     32.5400
# housing_median_age  20433.0      28.633094      12.591805      1.0000
# total_rooms         20433.0    2636.504233    2185.269567      2.0000
# total_bedrooms      20433.0     537.870553     421.385070      1.0000
# population          20433.0    1424.946949    1133.208490      3.0000
# households          20433.0     499.433465     382.299226      1.0000
# median_income       20433.0       3.871162       1.899291      0.4999
# median_house_value  20433.0  206864.413155  115435.667099  14999.0000
#
#                             25%          50%         75%          max
# longitude             -121.8000    -118.4900    -118.010    -114.3100
# latitude                33.9300      34.2600      37.720      41.9500
# housing_median_age      18.0000      29.0000      37.000      52.0000
# total_rooms           1450.0000    2127.0000    3143.000   39320.0000
# total_bedrooms         296.0000     435.0000     647.000    6445.0000
# population             787.0000    1166.0000    1722.000   35682.0000
# households             280.0000     409.0000     604.000    6082.0000
# median_income            2.5637       3.5365       4.744      15.0001
# median_house_value  119500.0000  179700.0000  264700.000  500001.0000

# %%
from sklearn.model_selection import train_test_split
x = data.drop(['median_house_value'], axis=1)
y = data['median_house_value']

# %%
x
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income
# 0             322         126         8.3252
# 1            2401        1138         8.3014
# 2             496         177         7.2574
# 3             558         219         5.6431
# 4             565         259         3.8462
# ...           ...         ...            ...
# 20635         845         330         1.5603
# 20636         356         114         2.5568
# 20637        1007         433         1.7000
# 20638         741         349         1.8672
# 20639        1387         530         2.3886
#
# [20433 rows x 8 columns]

# %%
y
# Out:
# 0        452600
# 1        358500
# 2        352100
# 3        341300
# 4        342200
#           ...
# 20635     78100
# 20636     77100
# 20637     92300
# 20638     84700
# 20639     89400
# Name: median_house_value, Length: 20433, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7128     -118.09     34.02                  33         4853          1105.0
# 8261     -118.18     33.74                  30         5915          1750.0
# 20501    -118.71     34.30                  20         1586           187.0
# 17021    -122.30     37.52                  32         2297           347.0
# 6135     -117.99     34.07                  35         1681           360.0
# ...          ...       ...                 ...          ...             ...
# 7125     -118.04     33.90                  36           15             5.0
# 6864     -118.14     34.05                  39         1880           367.0
# 5988     -117.72     34.10                  32         3241           895.0
# 9511     -123.22     39.15                  36         1166           216.0
# 16939    -122.32     37.55                  50         2501           433.0
#
#        population  households  median_income  median_house_value
# 7128         2855        1006         3.2622              208600
# 8261         2136        1503         4.0968              310000
# 20501         699         209         6.5483              335000
# 17021         871         342         8.1039              382200
# 6135         1648         373         2.4911              145900
# ...           ...         ...            ...                 ...
# 7125           15           6         0.4999              162500
# 6864          954         349         3.8750              236400
# 5988         1592         810         2.4952              181800
# 9511          504         203         3.5938              122100
# 16939        1050         410         4.6406              500001
#
# [16346 rows x 9 columns]

# %%
train_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
train_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.923406           -0.111788     0.046002
# latitude            -0.923406  1.000000            0.016431    -0.037622
# housing_median_age  -0.111788  0.016431            1.000000    -0.361999
# total_rooms          0.046002 -0.037622           -0.361999     1.000000
# total_bedrooms       0.069732 -0.067364           -0.321111     0.928919
# population           0.101016 -0.109798           -0.294908     0.854123
# households           0.055883 -0.071907           -0.303743     0.917945
# median_income       -0.017488 -0.079386           -0.118339     0.200447
# median_house_value  -0.046443 -0.144494            0.105999     0.134483
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.
# 5988     -117.72     34.10                  32     8.083946        6.797940
# 9511     -123.22     39.15                  36     7.062192        5.379897
# 16939    -122.32     37.55                  50     7.824846        6.073045
#
#        population  households  median_income  median_house_value  \
# 7128     7.957177    6.914731         3.2622              208600
# 8261     7.667158    7.315884         4.0968              310000
# 20501    6.551080    5.347108         6.5483              335000
# 17021    6.770789    5.837730         8.1039              382200
# 6135     7.407924    5.924256         2.4911              145900
# ...           ...         ...            ...                 ...
# 7125     2.772589    1.945910         0.4999              162500
# 6864     6.861711    5.857933         3.8750              236400
# 5988     7.373374    6.698268         2.4952              181800
# 9511     6.224558    5.318120         3.5938              122100
# 16939    6.957497    6.018593         4.6406              500001
#
#        bedroom_ratio  household_rooms
# 7128        0.825739         1.227460
# 8261        0.859826         1.187200
# 20501       0.710546         1.378241
# 17021       0.756119         1.325823
# 6135        0.792822         1.253784
# ...              ...              ...
# 7125        0.646241         1.424829
# 6864        0.783611         1.287068
# 5988        0.840919         1.206871
# 9511        0.761789         1.327949
# 16939       0.776123         1.300112
#
# [16346 rows x 11 columns]

# %%
x_test, y_test = test_data.drop(['median_house_value'], axis=1), test_data['median_house_value']

# %%
reg.score(x_test, y_test)
# Out:
# 0.6641660007719472

# %%
reg.score(x_train, y_train)
# Out:
# 0.6649305725825658

# %%
y_pred = reg.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
import math

# %%
math.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 66062.63278278623

# %%
data_new = x_train[:1]

# %%
reg.predict(data_new)
# Out:
# array([206983.81961844])

# %%
y_train[:1]
# Out:
# 7128    208600
# Name: median_house_value, dtype: int64

# %%
from sklearn.ensemble import RandomForestRegressor 

forest = RandomForestRegressor()

forest.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(x_test, y_test)
# Out:
# 0.7996029327442533

# %%
forest.score(x_train, y_train)
# Out:
# 0.9728942608658456

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

X = test_data.drop(['median_house_value'], axis=1)
Y = test_data['median_house_value']

# Split the training set into 
# training and validation set
X_train, X_valid, Y_train, Y_valid = train_test_split(
	X, Y, train_size=0.8, test_size=0.2, random_state=0)

# %%
from sklearn import svm
from sklearn.svm import SVC
from sklearn.metrics import mean_absolute_percentage_error

model_SVR = svm.SVR()
model_SVR.fit(X_train, Y_train)
Y_pred = model_SVR.predict(X_valid)

print(mean_absolute_percentage_error(Y_valid, Y_pred))
# Out:
# 0.5372390538946394

# %%
from sklearn.ensemble import RandomForestRegressor

model_RFR = RandomForestRegressor(n_estimators=10)
model_RFR.fit(X_train, Y_train)
Y_pred = model_RFR.predict(X_valid)

mean_absolute_percentage_error(Y_valid, Y_pred)
# Out:
# 0.24696140357461077

# %%
from sklearn.linear_model import LinearRegression

model_LR = LinearRegression()
model_LR.fit(X_train, Y_train)
Y_pred = model_LR.predict(X_valid)

print(mean_absolute_percentage_error(Y_valid, Y_pred))
# Out:
# 0.2661130234589181

# %%
data = data[["housing_median_age", "total_rooms", "total_bedrooms", "population", "median_income", "median_house_value"]]
data = data.rename({"median_house_value": "median_house_value"}, axis=1)
data.head()
# Out:
#    housing_median_age  total_rooms  total_bedrooms  population  median_income  \
# 0                  41          880           129.0         322         8.3252
# 1                  21         7099          1106.0        2401         8.3014
# 2                  52         1467           190.0         496         7.2574
# 3                  52         1274           235.0         558         5.6431
# 4                  52         1627           280.0         565         3.8462
#
#    median_house_value
# 0              452600
# 1              358500
# 2              352100
# 3              341300
# 4              342200

# %%
data  = data .dropna()
data.isnull().sum()
# Out:
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
x =  data .drop("median_house_value", axis=1)
y =  data ["median_house_value"]

# %%
from sklearn.linear_model import LinearRegression
linear_reg =  LinearRegression()
linear_reg.fit(x , y)
# Out:
# LinearRegression()

# %%
y_pred  = linear_reg.predict(x)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
error = np.sqrt(mean_squared_error(y , y_pred))

# %%
error
# Out:
# 76422.27233386412

# %%
from sklearn.tree import DecisionTreeRegressor
dec_tree_reg = DecisionTreeRegressor(random_state=0)
dec_tree_reg.fit(x , y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred = dec_tree_reg.predict(x)

# %%
error = np.sqrt(mean_squared_error(y , y_pred))
print("${:,.02f}".format(error))
# Out:
# $0.00

# %%
from sklearn.ensemble import RandomForestRegressor 
random_forest_reg = RandomForestRegressor(random_state=0)
random_forest_reg.fit(x , y)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred = random_forest_reg.predict(x)

# %%
error = np.sqrt(mean_squared_error(y, y_pred))
print("${:,.02f}".format(error))
# Out:
# $25,165.33

# %%
x
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                      41          880           129.0         322
# 1                      21         7099          1106.0        2401
# 2                      52         1467           190.0         496
# 3                      52         1274           235.0         558
# 4                      52         1627           280.0         565
# ...                   ...          ...             ...         ...
# 20635                  25         1665           374.0         845
# 20636                  18          697           150.0         356
# 20637                  17         2254           485.0        1007
# 20638                  18         1860           409.0         741
# 20639                  16         2785           616.0        1387
#
#        median_income
# 0             8.3252
# 1             8.3014
# 2             7.2574
# 3             5.6431
# 4             3.8462
# ...              ...
# 20635         1.5603
# 20636         2.5568
# 20637         1.7000
# 20638         1.8672
# 20639         2.3886
#
# [20433 rows x 5 columns]
